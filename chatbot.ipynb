# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
import gdown
from google.colab import userdata

# %%
from openai import OpenAI
import os
# Lade den API-Key aus der Umgebungsvariablen
api_key = userdata.get('openai.api_key')
#os.environ["OPENAI_API_KEY"] = api_key
#api_key = os.getenv("OPENAI_API_KEY")


if not api_key:
    raise ValueError("API key not found. Please set OPENAI_API_KEY before running the script.")

client = OpenAI(api_key=api_key)

def chat_with_gpt(prompt):
    response = client.chat.completions.create(
        model="gpt-5",  # oder "gpt-4.1-mini", falls gpt-5 nicht freigeschaltet ist
        messages=[
            {"role": "user", "content": prompt}
        ]
    )
    return response.choices[0].message.content

if __name__ == "__main__":
    print("Chatbot started. Type 'quit', 'exit', or 'bye' to stop.\n")

    while True:
        user_input = input("You: ")
        if user_input.lower() in ["quit", "exit", "bye"]:
            print("Chatbot: Goodbye! 👋")
            break

        response = chat_with_gpt(user_input)
        print("Chatbot:", response)
# Out:
# Chatbot started. Type 'quit', 'exit', or 'bye' to stop.
#
# You: Was ist der Baum des Lebens?
# Chatbot: Der „Baum des Lebens“ ist ein vieldeutiges Symbol/Modell, das je nach Kontext Unterschiedliches meint:
#
# - Biologie/Evolution: Ein phylogenetischer Stammbaum, der die Verwandtschaft aller Lebewesen darstellt (von Darwin bis zu heutigen DNA‑basierten Stammbäumen mit Bakterien, Archaeen und Eukaryoten). Bei Mikroben ist das Bild teils eher ein Netz wegen horizontalem Gentransfer.
#
# - Bibel/Abrahamitische Traditionen: In Genesis steht der Baum des Lebens für Unsterblichkeit (neben dem Baum der Erkenntnis); in der Offenbarung erscheint er als Bild für Heil und neues Leben. Im Judentum ist „Etz Chajim“ zugleich ein poetischer Name der Tora. Im Islam gibt es verwandte Motive wie den Lote‑Baum (Sidrat al‑Muntaha) und die „Schajaratu’l‑Khuld“ (Baum der Unsterblichkeit).
#
# - Kabbala (Jüdische Mystik): Ein Diagramm aus 10 Sefirot und 22 Pfaden, das die Emanationen Gottes und den geistigen Weg des Menschen beschreibt.
#
# - Nordisch/Germanisch: Yggdrasil, der Weltenbaum, der die verschiedenen Bereiche der Welt verbindet (Achse der Welt).
#
# - Andere Kulturen: Der keltische Baum des Lebens (Verbindung von Himmel und Erde, Kreislauf des Lebens), mesoamerikanische Weltenbäume, der indische Aśvattha/Peepal‑Baum und der Wunschbaum Kalpavriksha.
#
# - Kunst/Alltagssymbolik: Beliebtes Motiv in Kunst, Schmuck und Tätowierungen für Verbundenheit, Wachstum und Erneuerung.
#
# Wenn du eine bestimmte Tradition oder den biologischen Stammbaum meinst, sag gern welche – dann gehe ich detaillierter darauf ein.
# You: Was ist eine Regression?
# Chatbot: Kurz gesagt bedeutet Regression “Rückgang” oder “Rückkehr” – der genaue Sinn hängt vom Fachgebiet ab:
#
# - Statistik/Machine Learning: Verfahren zur Modellierung eines Zusammenhangs zwischen Variablen und zur Vorhersage kontinuierlicher Werte (z. B. lineare Regression y = β0 + β1x + ε). Wichtige Begriffe: MSE, R², Regularisierung (Lasso/Ridge).
# - Statistik-Phänomen: Regression zum Mittelwert – extreme Messwerte tendieren bei Wiederholung näher am Durchschnitt zu liegen.
# - Softwareentwicklung: Regressionsfehler – eine Änderung bricht zuvor funktionierende Funktionen; Gegenmaßnahme: Regressionstests.
# - Psychologie: Abwehrmechanismus – unter Stress Rückfall auf frühere, kindlichere Verhaltensmuster.
# - Medizin/Onkologie: Rückbildung von Symptomen oder Tumorgröße (partielle oder vollständige Regression).
#
# In welchem Kontext interessiert dich “Regression” genau?
# You: quit
# Chatbot: Goodbye! 👋
